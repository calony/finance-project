# %% [markdown]
# ## Get the Data
# Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**)

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas_datareader as pdr
import datetime

start = datetime.datetime(1970,1,1)
ends = datetime.datetime(2019,1,1)

SP500 = pdr.get_data_yahoo('^GSPC',start,ends)
ACWI = pdr.get_data_yahoo('ACWI',start,ends)
ACWX = pdr.get_data_yahoo('ACWI',start,ends)
USSBX = pdr.get_data_yahoo('USSBX',start,ends)

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
symbol_list = ['SP500', 'ACWI', 'ACWX', 'USSBX']
df_list = [SP500, ACWI, ACWX, USSBX]

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
df= pd.concat(df_list, axis=1, keys=index_list)
df.columns.names = ['symbol_list','Price Info']

# %%
close_price = df.xs(key='Close', axis=1, level='Price Info')
close_price = close_price.fillna(0)
close_price.head()
# Out:
# symbol_list      SP500  ACWI  ACWX  USSBX
# Date
# 1970-01-02   93.000000   0.0   0.0    0.0
# 1970-01-05   93.459999   0.0   0.0    0.0
# 1970-01-06   92.820000   0.0   0.0    0.0
# 1970-01-07   92.629997   0.0   0.0    0.0
# 1970-01-08   92.680000   0.0   0.0    0.0

# %%
# calculating price differences at a fixed time interval
returns =SP500.pct_change(periods=365)

# %%
#plot time vs the 'Close' price for SP500
SP500['Close'].plot()

# %%
#plot the returns based on 'Close' price
returns['Close'].plot()

# %%
#plot the returns (based on 'Close' price) that are negative
returns['Close'][returns['Close']<0].plot()

# %%
#plot time vs the close price for different indices
close_price.plot()
